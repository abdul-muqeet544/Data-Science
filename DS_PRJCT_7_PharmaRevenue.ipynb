# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("pharma_companies_financials.csv")

print("First 5 Rows")
print(df.head())
# Out:
# First 5 Rows
#    year       company_name ticker country_iso3             segment  \
# 0  2010  Johnson & Johnson    JNJ          USA  diversified_pharma
# 1  2011  Johnson & Johnson    JNJ          USA  diversified_pharma
# 2  2012  Johnson & Johnson    JNJ          USA  diversified_pharma
# 3  2013  Johnson & Johnson    JNJ          USA  diversified_pharma
# 4  2014  Johnson & Johnson    JNJ          USA  diversified_pharma
#
#    revenue_usd_bn  operating_margin_pct  operating_income_usd_bn  \
# 0           62.17                  18.9                    11.74
# 1           64.74                  24.8                    16.07
# 2           61.30                  18.1                    11.09
# 3           66.96                  21.1                    14.10
# 4           68.37                  19.4                    13.29
#
#    rd_spend_usd_bn  pipeline_size_est
# 0             7.46                 74
# 1             7.77                 75
# 2             7.36                 74
# 3             8.03                 76
# 4             8.20                 76

# %%
print("\nShape of Dataset")
print(df.shape)
# Out:
# Shape of Dataset
# (489, 10)

# %%
print("\nDataset Information")
print(df.info())
# Out:
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     489 non-null    int64
#  1   company_name             489 non-null    object
#  2   ticker                   489 non-null    object
#  3   country_iso3             489 non-null    object
#  4   segment                  489 non-null    object
#  5   revenue_usd_bn           489 non-null    float64
#  6   operating_margin_pct     489 non-null    float64
#  7   operating_income_usd_bn  489 non-null    float64
#  8   rd_spend_usd_bn          489 non-null    float64
#  9   pipeline_size_est        489 non-null    int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 38.3+ KB
# None

# %%
print("\nStatistical Summary")
print(df.describe())
# Out:
# Statistical Summary
#               year  revenue_usd_bn  operating_margin_pct  \
# count   489.000000      489.000000            489.000000
# mean   2018.220859       28.596769             25.432515
# std       4.864169       20.254987              8.102994
# min    2010.000000        0.060000            -12.700000
# 25%    2014.000000       13.770000             22.100000
# 50%    2018.000000       24.160000             27.200000
# 75%    2022.000000       43.160000             30.100000
# max    2026.000000       98.000000             45.500000
#
#        operating_income_usd_bn  rd_spend_usd_bn  pipeline_size_est
# count               489.000000       489.000000         489.000000
# mean                  7.345603         4.703190          59.036810
# std                   5.557236         3.382745          36.943226
# min                  -0.710000         0.020000           3.000000
# 25%                   3.090000         1.880000          19.000000
# 50%                   6.170000         4.080000          69.000000
# 75%                  10.710000         7.050000          92.000000
# max                  37.040000        17.590000         128.000000

# %%
print("\nMissing Values")
print(df.isnull().sum())

df = df.dropna()
# Out:
# Missing Values
# year                       0
# company_name               0
# ticker                     0
# country_iso3               0
# segment                    0
# revenue_usd_bn             0
# operating_margin_pct       0
# operating_income_usd_bn    0
# rd_spend_usd_bn            0
# pipeline_size_est          0
# dtype: int64

# %%
encoder = LabelEncoder()

categorical_columns = [
    "company_name",
    "ticker",
    "country_iso3",
    "segment"
]

for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

# %%
X = df.drop("revenue_usd_bn", axis=1)

y = df["revenue_usd_bn"]

print("\nFeatures")
print(X.head())

print("\nTarget")
print(y.head())
# Out:
# Features
#    year  company_name  ticker  country_iso3  segment  operating_margin_pct  \
# 0  2010            15      15             9        3                  18.9
# 1  2011            15      15             9        3                  24.8
# 2  2012            15      15             9        3                  18.1
# 3  2013            15      15             9        3                  21.1
# 4  2014            15      15             9        3                  19.4
#
#    operating_income_usd_bn  rd_spend_usd_bn  pipeline_size_est
# 0                    11.74             7.46                 74
# 1                    16.07             7.77                 75
# 2                    11.09             7.36                 74
# 3                    14.10             8.03                 76
# 4                    13.29             8.20                 76
#
# Target
# 0    62.17
# 1    64.74
# 2    61.30
# 3    66.96
# 4    68.37
# Name: revenue_usd_bn, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("\nTraining Shape :", X_train.shape)
print("Testing Shape :", X_test.shape)
# Out:
# Training Shape : (391, 9)
# Testing Shape : (98, 9)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LinearRegression()


model.fit(X_train, y_train)

print("\nModel Trained Successfully")
# Out:
# Model Trained Successfully

# %%
y_pred = model.predict(X_test)


comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

# %%
print("\nActual vs Predicted")
print(comparison.head(10))
# Out:
# Actual vs Predicted
#    Actual  Predicted
# 0   39.92  40.437025
# 1   69.67  70.814693
# 2   30.66  28.817559
# 3   13.32   9.205981
# 4   29.70  28.498980
# 5   10.50   8.314645
# 6   55.62  51.591560
# 7   17.08  17.395577
# 8   22.28  14.464935
# 9   25.55  26.238708

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Performance")
print("Mean Absolute Error :", mae)
print("Mean Squared Error :", mse)
print("Root Mean Squared Error :", rmse)
print("R2 Score :", r2)
print("Model Accuracy (R2 %) :", r2 * 100)
# Out:
# Model Performance
# Mean Absolute Error : 2.920829832049217
# Mean Squared Error : 20.83344746288124
# Root Mean Squared Error : 4.564367148124835
# R2 Score : 0.9506625433958825
# Model Accuracy (R2 %) : 95.06625433958826
